# %% [markdown]
# (test:myst-root)=
# # MyST / Sphinx Syntax Test Notebook
#
# This notebook is a compact test artifact for validating MyST and Sphinx-aware rendering of markdown cells.
#
# It includes examples of the syntax patterns used in this course, along with examples for the MyST extensions enabled in `content/_config.yml`.

# %% [markdown]
# ## What This Covers
#
# - label anchors like `(label)=`
# - cross-references with `{ref}` and `{numref}`
# - fenced directives such as `figure`, `image`, `note`, `warning`, and `sidebar`
# - colon-fence directives such as `note`, `warning`, and `table`
# - inline and display math
# - definition lists
# - raw HTML blocks enabled by `html_admonition` and `html_image`
# - parser behaviors such as `linkify`, `smartquotes`, and `replacements`
# - citation syntax with `{cite}`

# %% [markdown]
# (test:crossrefs)=
# ## Cross-Reference Samples
#
# This section demonstrates the role syntax most important to this course.
#
# - Section reference: {ref}`test:math`
# - Figure reference: {numref}`Figure %s <test:book-cover-figure>`
# - Table reference: {numref}`Table %s <test:sample-table>`
# - Section numbering reference: {numref}`Section %s <test:math>`
# - Citation sample: {cite}`grotenhuis2018`
#
# If bibliography support is not wired up in the renderer, the citation should degrade gracefully rather than disappear.

# %% [markdown]
# ```{note}
# This is a fenced `note` directive. It should render as an admonition block with a visible title.
# ```

# %% [markdown]
# ```{warning}
# This is a fenced `warning` directive. It should be visually distinct from a note.
# ```

# %% [markdown]
# ```{sidebar} Why This Matters
# Sidebars are used in the course to call out supporting explanations without interrupting the main flow.
# ```

# %% [markdown]
# ```{figure} figures/book-cover.png
# ---
# name: test:book-cover-figure
# width: 240px
# ---
# A `figure` directive with a label, image asset, and caption.
# ```

# %% [markdown]
# ```{image} figures/book-cover.png
# :alt: Book cover image rendered with the `image` directive
# :width: 180px
# ```

# %% [markdown]
# :::{note}
# This is a colon-fence note. The repo enables the `colon_fence` extension, so this syntax should be handled the same way as the fenced note directive.
# :::

# %% [markdown]
# :::{warning}
# This is a colon-fence warning. It is commonly used in the course notebooks.
# :::

# %% [markdown]
# :::{table} Sample labeled table for `{numref}` testing.
# :name: test:sample-table
#
# | Feature | Expected Behavior |
# |---|---|
# | `figure` | Registers a label and caption |
# | `table` | Registers a label and caption |
# | `{numref}` | Resolves to a numbered link |
#
# :::

# %% [markdown]
# ## Definition List Sample
#
# MyST
# : A Markdown flavor used by Jupyter Book and Sphinx.
#
# Directive
# : A block-level syntax form such as `figure`, `note`, or `table`.
#
# Role
# : An inline syntax form such as `{ref}` or `{numref}`.

# %% [markdown]
# (test:math)=
# ## Math Samples
#
# Inline math should render correctly, for example $a^2 + b^2 = c^2$.
#
# Display math should also render:
#
# $$
# \hat{\theta} = (X^T X)^{-1} X^T y
# $$
#
# An AMS-style block is included below for `amsmath` support:
#
# $$
# \begin{aligned}
# f(x) &= x^2 + 2x + 1 \\
#      &= (x + 1)^2
# \end{aligned}
# $$

# %% [markdown]
# ## Text Behavior Samples
#
# Raw URL for `linkify`: https://mystmd.org/guide/overview
#
# Smartquotes / replacements sample: "quoted text", 'single quotes', and a range such as 2003--2009.
#
# Substitution-style sample token: |today|.
#
# If substitutions are not configured, the renderer should fail gracefully rather than corrupt the surrounding markdown.

# %% [markdown]
# ## Final Cross-Reference Roundup
#
# This notebook started at {ref}`test:myst-root`.
#
# The numbered figure is {numref}`Figure %s <test:book-cover-figure>`.
#
# The numbered table is {numref}`Table %s <test:sample-table>`.
#
# The math section is {ref}`test:math`.
